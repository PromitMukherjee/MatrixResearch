# %% [markdown]
# # Experiment 7: Latent Operator
#
# This notebook investigates whether Encoded(A) and Encoded(B) can be combined to predict Encoded(C).

# %%
import sys
sys.path.append('..')
from src.models.latent_operator import LatentOperator
print('Latent Operator instantiated successfully.')
