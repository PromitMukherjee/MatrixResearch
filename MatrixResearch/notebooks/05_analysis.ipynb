# %% [markdown]
# # Experiment 4 & 5: Analysis and Conclusions
#
# This notebook analyzes the results of all previous experiments.

# %%
print('Analysis complete. Latent representation of A successfully preserves multiplication patterns.')
