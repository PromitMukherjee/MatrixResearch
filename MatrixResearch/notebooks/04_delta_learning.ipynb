# %% [markdown]
# # Experiment 3: Delta Learning
#
# This notebook trains a model to predict Delta = C - A.

# %%
import os
import sys
sys.path.append('..')
from src.training.train_delta_model import run_delta_training

model = run_delta_training(size=16)
