# %% [markdown]
# # Experiment 2: Latent Matrix Multiplication
#
# This notebook trains a model to predict C = A @ B given only the latent representation of A (Z_A) and matrix B.

# %%
import os
import sys
sys.path.append('..')
from src.training.train_latent_multiplier import run_latent_training

model = run_latent_training(size=16, latent_dim=32, ae_checkpoint='../checkpoints/autoencoder/size_16_latent_32/best_model.pt')
