# %% [markdown]
# # Experiment 6: Compression Frontier
#
# This notebook evaluates the trade-off between latent dimension size, compression ratio, and multiplication accuracy.

# %%
import sys
sys.path.append('..')
from src.visualization.performance_plots import plot_compression_frontier

# Placeholder for actual swept data
latent_dims = [2, 4, 8, 16, 32, 64, 128, 256]
accuracies = [0.1, 0.3, 0.6, 0.85, 0.95, 0.98, 0.99, 0.999]
compression_ratios = [1024/d for d in latent_dims]

plot_compression_frontier(latent_dims, accuracies, compression_ratios, save_path='../reports/figures/frontier.png')
